# %%
import pandas as pd
import numpy as np
data = pd.read_csv('wine_red.csv',sep = ';')

# copy the data
df_scaled = data.copy()
for column in df_scaled.columns:
    df_scaled[column] = df_scaled[column]  / df_scaled[column].abs().max()

df_scaled_shape = df_scaled.shape
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.465409          0.443038         0.00        0.122581   0.124386
# 1       0.490566          0.556962         0.00        0.167742   0.160393
# 2       0.490566          0.481013         0.04        0.148387   0.150573
# 3       0.704403          0.177215         0.56        0.122581   0.122750
# 4       0.465409          0.443038         0.00        0.122581   0.124386
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.152778              0.117647  0.994132  0.875312      0.280
# 1             0.347222              0.231834  0.993135  0.798005      0.340
# 2             0.208333              0.186851  0.993335  0.812968      0.325
# 3             0.236111              0.207612  0.994331  0.788030      0.290
# 4             0.152778              0.117647  0.994132  0.875312      0.280
#
#     alcohol  quality
# 0  0.630872    0.625
# 1  0.657718    0.625
# 2  0.657718    0.625
# 3  0.657718    0.750
# 4  0.630872    0.625

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from numpy import random


def train_AE(df_scaled, df_scaled_shape, epch = 400):
    #--------------------Define dataset-------------------------
    class StateDataset(Dataset):

        def __init__(self):
            # data loading
            state = np.float32(data)
            self.st = torch.from_numpy(state)
            self.n_samples = state.shape[0]

        def __getitem__(self, index):
            return self.st[index]

        def __len__(self):
            return self.n_samples

    dataset = StateDataset()

    # Dataloader loads data for training
    loader = DataLoader(dataset = dataset,batch_size = 64, shuffle = True)

    # Define Autoencoder architecture
    class AE(torch.nn.Module):
        def __init__(self):
            super().__init__()

            self.vec_shape = df_scaled_shape
            self.encoder = torch.nn.Sequential(
                torch.nn.Linear(self.vec_shape[1], 8),
                torch.nn.ELU(),
                torch.nn.Linear(8,4)
            )

            # Building an linear decoder with Linear
            # layer followed by ELU activation function
            self.decoder = torch.nn.Sequential(
                torch.nn.Linear(4,8),
                torch.nn.ELU(),
                torch.nn.Linear(8, self.vec_shape[1]),
            )

        def forward(self, x):
            encoded = self.encoder(x)
            decoded = self.decoder(encoded)
            return decoded

    model = AE() # Model Initialization
    print(model)

    loss_function = torch.nn.MSELoss()  # Validation using MSE Loss function

    optimizer = torch.optim.Adam(model.parameters(),
                             lr = 1e-3,
                             weight_decay = 1e-5) # Using an Adam Optimizer

    #------------Training loop-------------------------------
    epochs = epch
    outputs = []
    losses = []
    for epoch in range(epochs):
        for i,(a) in enumerate(loader):
          reconstructed = model(a) # Output of Autoencoder

          # Calculating the loss function
          loss = loss_function(reconstructed,a)

          # The gradients are set to zero,
          # the the gradient is computed and stored.
          # .step() performs parameter update
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          # Storing the losses in a list for plotting
          if i%50 == 0:
              losses.append(loss)
        print(f'Epoch:{epoch+1}, Loss:{loss.item():.4f}')
        outputs.append((epochs, a, reconstructed))
    mod = model.state_dict()
    # Defining the Plot Style
    plt.style.use('fivethirtyeight')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')

    # Plotting the last 100 values
    plt.plot(losses)
    plt.show()

    return mod

# %%
mod = train_AE(df_scaled, df_scaled_shape)
# Out:
# AE(
#   (encoder): Sequential(
#     (0): Linear(in_features=12, out_features=8, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=8, out_features=4, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=4, out_features=8, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=8, out_features=12, bias=True)
#   )
# )
# Epoch:1, Loss:260.4030
# Epoch:2, Loss:368.2685
# Epoch:3, Loss:272.8694
# Epoch:4, Loss:192.4794
# Epoch:5, Loss:106.9812
# Epoch:6, Loss:53.6977
# Epoch:7, Loss:21.3262
# Epoch:8, Loss:15.5224
# Epoch:9, Loss:14.4979
# Epoch:10, Loss:12.7306
# Epoch:11, Loss:13.3861
# Epoch:12, Loss:10.4908
# Epoch:13, Loss:11.6512
# Epoch:14, Loss:8.6800
# Epoch:15, Loss:9.4222
# Epoch:16, Loss:9.5505
# Epoch:17, Loss:8.5616
# Epoch:18, Loss:7.6306
# Epoch:19, Loss:9.3655
# Epoch:20, Loss:13.2397
# Epoch:21, Loss:6.4368
# Epoch:22, Loss:7.9182
# Epoch:23, Loss:6.9777
# Epoch:24, Loss:14.9599
# Epoch:25, Loss:7.2040
# Epoch:26, Loss:7.1705
# Epoch:27, Loss:7.0146
# Epoch:28, Loss:6.8819
# Epoch:29, Loss:6.6251
# Epoch:30, Loss:7.7567
# Epoch:31, Loss:5.2807
# Epoch:32, Loss:4.5790
# Epoch:33, Loss:7.1977
# Epoch:34, Loss:3.8092
# Epoch:35, Loss:3.7197
# Epoch:36, Loss:6.5018
# Epoch:37, Loss:7.4525
# Epoch:38, Loss:5.0671
# Epoch:39, Loss:7.1938
# Epoch:40, Loss:6.8754
# Epoch:41, Loss:4.8773
# Epoch:42, Loss:5.7593
# Epoch:43, Loss:6.7851
# Epoch:44, Loss:6.6638
# Epoch:45, Loss:7.3853
# Epoch:46, Loss:4.9282
# Epoch:47, Loss:4.6322
# Epoch:48, Loss:5.5850
# Epoch:49, Loss:3.0555
# Epoch:50, Loss:6.6207
# Epoch:51, Loss:3.4626
# Epoch:52, Loss:4.4161
# Epoch:53, Loss:5.7802
# Epoch:54, Loss:5.1234
# Epoch:55, Loss:5.1766
# Epoch:56, Loss:7.2977
# Epoch:57, Loss:5.4440
# Epoch:58, Loss:4.0462
# Epoch:59, Loss:6.0395
# Epoch:60, Loss:6.1742
# Epoch:61, Loss:5.1707
# Epoch:62, Loss:4.9620
# Epoch:63, Loss:4.8490
# Epoch:64, Loss:2.8129
# Epoch:65, Loss:4.9747
# Epoch:66, Loss:7.3391
# Epoch:67, Loss:4.3989
# Epoch:68, Loss:2.9334
# Epoch:69, Loss:3.5860
# Epoch:70, Loss:5.6547
# Epoch:71, Loss:4.4959
# Epoch:72, Loss:4.7669
# Epoch:73, Loss:5.9464
# Epoch:74, Loss:4.3732
# Epoch:75, Loss:5.6777
# Epoch:76, Loss:5.0330
# Epoch:77, Loss:7.1503
# Epoch:78, Loss:4.4046
# Epoch:79, Loss:5.3338
# Epoch:80, Loss:4.7983
# Epoch:81, Loss:4.2731
# Epoch:82, Loss:5.6820
# Epoch:83, Loss:4.7084
# Epoch:84, Loss:4.7283
# Epoch:85, Loss:5.6404
# Epoch:86, Loss:6.4416
# Epoch:87, Loss:3.7391
# Epoch:88, Loss:5.8806
# Epoch:89, Loss:4.2634
# Epoch:90, Loss:6.5292
# Epoch:91, Loss:4.8982
# Epoch:92, Loss:5.7420
# Epoch:93, Loss:7.2834
# Epoch:94, Loss:4.9366
# Epoch:95, Loss:4.4259
# Epoch:96, Loss:5.3452
# Epoch:97, Loss:4.9224
# Epoch:98, Loss:5.1544
# Epoch:99, Loss:6.5017
# Epoch:100, Loss:3.7615
# Epoch:101, Loss:4.5566
# Epoch:102, Loss:5.8782
# Epoch:103, Loss:4.8721
# Epoch:104, Loss:3.7541
# Epoch:105, Loss:4.5650
# Epoch:106, Loss:6.8476
# Epoch:107, Loss:4.3654
# Epoch:108, Loss:6.4029
# Epoch:109, Loss:4.2929
# Epoch:110, Loss:3.4325
# Epoch:111, Loss:3.6346
# Epoch:112, Loss:3.4625
# Epoch:113, Loss:2.8919
# Epoch:114, Loss:1.8383
# Epoch:115, Loss:1.2788
# Epoch:116, Loss:0.9393
# Epoch:117, Loss:0.5531
# Epoch:118, Loss:0.7019
# Epoch:119, Loss:0.8305
# Epoch:120, Loss:0.5335
# Epoch:121, Loss:0.3559
# Epoch:122, Loss:0.5833
# Epoch:123, Loss:0.6555
# Epoch:124, Loss:0.3687
# Epoch:125, Loss:0.4964
# Epoch:126, Loss:0.4235
# Epoch:127, Loss:0.3761
# Epoch:128, Loss:0.7480
# Epoch:129, Loss:0.5731
# Epoch:130, Loss:0.3258
# Epoch:131, Loss:0.6130
# Epoch:132, Loss:0.4097
# Epoch:133, Loss:0.5005
# Epoch:134, Loss:0.7496
# Epoch:135, Loss:0.4298
# Epoch:136, Loss:0.5116
# Epoch:137, Loss:0.4772
# Epoch:138, Loss:0.4422
# Epoch:139, Loss:0.4214
# Epoch:140, Loss:0.3908
# Epoch:141, Loss:0.3177
# Epoch:142, Loss:0.3721
# Epoch:143, Loss:0.4314
# Epoch:144, Loss:0.3201
# Epoch:145, Loss:0.3025
# Epoch:146, Loss:0.3471
# Epoch:147, Loss:0.4842
# Epoch:148, Loss:0.4779
# Epoch:149, Loss:0.4029
# Epoch:150, Loss:0.3950
# Epoch:151, Loss:0.3515
# Epoch:152, Loss:0.6159
# Epoch:153, Loss:0.5828
# Epoch:154, Loss:0.3712
# Epoch:155, Loss:0.4605
# Epoch:156, Loss:0.6771
# Epoch:157, Loss:0.3341
# Epoch:158, Loss:0.2939
# Epoch:159, Loss:0.3430
# Epoch:160, Loss:0.4873
# Epoch:161, Loss:0.3724
# Epoch:162, Loss:0.4258
# Epoch:163, Loss:0.3109
# Epoch:164, Loss:0.4566
# Epoch:165, Loss:0.7162
# Epoch:166, Loss:0.3067
# Epoch:167, Loss:0.4191
# Epoch:168, Loss:0.4009
# Epoch:169, Loss:0.3574
# Epoch:170, Loss:0.5819
# Epoch:171, Loss:0.4253
# Epoch:172, Loss:0.4080
# Epoch:173, Loss:0.5098
# Epoch:174, Loss:0.5197
# Epoch:175, Loss:0.3709
# Epoch:176, Loss:0.5537
# Epoch:177, Loss:0.4123
# Epoch:178, Loss:0.2456
# Epoch:179, Loss:0.4947
# Epoch:180, Loss:0.3488
# Epoch:181, Loss:0.3747
# Epoch:182, Loss:0.5038
# Epoch:183, Loss:0.3834
# Epoch:184, Loss:0.3445
# Epoch:185, Loss:0.3174
# Epoch:186, Loss:0.5401
# Epoch:187, Loss:0.3938
# Epoch:188, Loss:0.3059
# Epoch:189, Loss:0.4599
# Epoch:190, Loss:0.5082
# Epoch:191, Loss:0.5668
# Epoch:192, Loss:0.3539
# Epoch:193, Loss:0.3835
# Epoch:194, Loss:0.3568
# Epoch:195, Loss:0.3114
# Epoch:196, Loss:0.3505
# Epoch:197, Loss:0.3510
# Epoch:198, Loss:0.2782
# Epoch:199, Loss:0.3365
# Epoch:200, Loss:0.5289
# Epoch:201, Loss:0.4021
# Epoch:202, Loss:0.3215
# Epoch:203, Loss:0.5131
# Epoch:204, Loss:0.3511
# Epoch:205, Loss:0.2830
# Epoch:206, Loss:0.4343
# Epoch:207, Loss:0.3106
# Epoch:208, Loss:0.3740
# Epoch:209, Loss:0.3187
# Epoch:210, Loss:0.5955
# Epoch:211, Loss:0.3956
# Epoch:212, Loss:0.3830
# Epoch:213, Loss:0.3329
# Epoch:214, Loss:0.4509
# Epoch:215, Loss:0.2450
# Epoch:216, Loss:0.2911
# Epoch:217, Loss:0.3744
# Epoch:218, Loss:0.7083
# Epoch:219, Loss:0.3457
# Epoch:220, Loss:0.2972
# Epoch:221, Loss:0.3112
# Epoch:222, Loss:0.2550
# Epoch:223, Loss:0.4266
# Epoch:224, Loss:0.4855
# Epoch:225, Loss:0.5872
# Epoch:226, Loss:0.4855
# Epoch:227, Loss:0.5795
# Epoch:228, Loss:0.7625
# Epoch:229, Loss:0.3326
# Epoch:230, Loss:0.3545
# Epoch:231, Loss:0.2573
# Epoch:232, Loss:0.2819
# Epoch:233, Loss:0.2943
# Epoch:234, Loss:0.2930
# Epoch:235, Loss:0.3906
# Epoch:236, Loss:0.3040
# Epoch:237, Loss:0.2774
# Epoch:238, Loss:0.3259
# Epoch:239, Loss:0.3531
# Epoch:240, Loss:0.3474
# Epoch:241, Loss:0.2999
# Epoch:242, Loss:0.3116
# Epoch:243, Loss:0.3228
# Epoch:244, Loss:0.2958
# Epoch:245, Loss:0.3707
# Epoch:246, Loss:0.4506
# Epoch:247, Loss:0.2856
# Epoch:248, Loss:0.4129
# Epoch:249, Loss:0.3751
# Epoch:250, Loss:0.3186
# Epoch:251, Loss:0.5471
# Epoch:252, Loss:0.2521
# Epoch:253, Loss:0.3394
# Epoch:254, Loss:0.2696
# Epoch:255, Loss:0.4771
# Epoch:256, Loss:0.4064
# Epoch:257, Loss:0.3027
# Epoch:258, Loss:0.3853
# Epoch:259, Loss:0.5459
# Epoch:260, Loss:0.3091
# Epoch:261, Loss:0.3891
# Epoch:262, Loss:0.3221
# Epoch:263, Loss:0.2811
# Epoch:264, Loss:0.3663
# Epoch:265, Loss:0.4765
# Epoch:266, Loss:0.5655
# Epoch:267, Loss:0.3596
# Epoch:268, Loss:0.4004
# Epoch:269, Loss:0.6251
# Epoch:270, Loss:0.2694
# Epoch:271, Loss:0.2741
# Epoch:272, Loss:0.3480
# Epoch:273, Loss:0.4144
# Epoch:274, Loss:0.4324
# Epoch:275, Loss:0.4690
# Epoch:276, Loss:0.3032
# Epoch:277, Loss:0.2721
# Epoch:278, Loss:0.2231
# Epoch:279, Loss:0.3205
# Epoch:280, Loss:0.4721
# Epoch:281, Loss:0.5818
# Epoch:282, Loss:0.3825
# Epoch:283, Loss:0.2344
# Epoch:284, Loss:0.2669
# Epoch:285, Loss:0.3178
# Epoch:286, Loss:0.3603
# Epoch:287, Loss:0.2777
# Epoch:288, Loss:0.3086
# Epoch:289, Loss:0.5043
# Epoch:290, Loss:0.2728
# Epoch:291, Loss:0.2999
# Epoch:292, Loss:0.4071
# Epoch:293, Loss:0.3188
# Epoch:294, Loss:0.5828
# Epoch:295, Loss:0.2542
# Epoch:296, Loss:0.3213
# Epoch:297, Loss:0.4722
# Epoch:298, Loss:0.3351
# Epoch:299, Loss:0.3332
# Epoch:300, Loss:0.2906
# Epoch:301, Loss:0.4077
# Epoch:302, Loss:0.3219
# Epoch:303, Loss:0.4346
# Epoch:304, Loss:0.2807
# Epoch:305, Loss:0.6182
# Epoch:306, Loss:0.3957
# Epoch:307, Loss:0.2593
# Epoch:308, Loss:0.2972
# Epoch:309, Loss:0.1975
# Epoch:310, Loss:0.2249
# Epoch:311, Loss:0.2773
# Epoch:312, Loss:0.4355
# Epoch:313, Loss:0.2884
# Epoch:314, Loss:0.2665
# Epoch:315, Loss:0.4399
# Epoch:316, Loss:0.2519
# Epoch:317, Loss:0.4077
# Epoch:318, Loss:0.2757
# Epoch:319, Loss:0.2122
# Epoch:320, Loss:0.2248
# Epoch:321, Loss:0.3152
# Epoch:322, Loss:0.6324
# Epoch:323, Loss:0.2969
# Epoch:324, Loss:0.2715
# Epoch:325, Loss:0.2620
# Epoch:326, Loss:0.3088
# Epoch:327, Loss:0.3475
# Epoch:328, Loss:0.2769
# Epoch:329, Loss:0.2764
# Epoch:330, Loss:0.2860
# Epoch:331, Loss:0.5201
# Epoch:332, Loss:0.3030
# Epoch:333, Loss:0.3589
# Epoch:334, Loss:0.3693
# Epoch:335, Loss:0.2770
# Epoch:336, Loss:0.1973
# Epoch:337, Loss:0.2179
# Epoch:338, Loss:0.2750
# Epoch:339, Loss:0.2271
# Epoch:340, Loss:0.2483
# Epoch:341, Loss:0.4233
# Epoch:342, Loss:0.4609
# Epoch:343, Loss:0.6394
# Epoch:344, Loss:0.4621
# Epoch:345, Loss:0.4805
# Epoch:346, Loss:0.4552
# Epoch:347, Loss:0.3641
# Epoch:348, Loss:0.2694
# Epoch:349, Loss:0.2268
# Epoch:350, Loss:0.3436
# Epoch:351, Loss:0.5679
# Epoch:352, Loss:0.2568
# Epoch:353, Loss:0.4321
# Epoch:354, Loss:0.7053
# Epoch:355, Loss:0.2868
# Epoch:356, Loss:0.4887
# Epoch:357, Loss:0.2702
# Epoch:358, Loss:0.2271
# Epoch:359, Loss:0.2400
# Epoch:360, Loss:0.3265
# Epoch:361, Loss:0.2105
# Epoch:362, Loss:0.5135
# Epoch:363, Loss:0.3865
# Epoch:364, Loss:0.4079
# Epoch:365, Loss:0.2159
# Epoch:366, Loss:0.2467
# Epoch:367, Loss:0.3180
# Epoch:368, Loss:0.2722
# Epoch:369, Loss:0.3396
# Epoch:370, Loss:0.1971
# Epoch:371, Loss:0.1878
# Epoch:372, Loss:0.2334
# Epoch:373, Loss:0.2018
# Epoch:374, Loss:0.3064
# Epoch:375, Loss:0.2356
# Epoch:376, Loss:0.2938
# Epoch:377, Loss:0.3239
# Epoch:378, Loss:0.4560
# Epoch:379, Loss:0.2630
# Epoch:380, Loss:0.5668
# Epoch:381, Loss:0.3162
# Epoch:382, Loss:0.5596
# Epoch:383, Loss:0.2911
# Epoch:384, Loss:0.2522
# Epoch:385, Loss:0.3664
# Epoch:386, Loss:0.3995
# Epoch:387, Loss:0.2765
# Epoch:388, Loss:0.4101
# Epoch:389, Loss:0.2764
# Epoch:390, Loss:0.3148
# Epoch:391, Loss:0.4089
# Epoch:392, Loss:0.2217
# Epoch:393, Loss:0.3984
# Epoch:394, Loss:0.5106
# Epoch:395, Loss:0.4218
# Epoch:396, Loss:0.3874
# Epoch:397, Loss:0.3866
# Epoch:398, Loss:0.3009
# Epoch:399, Loss:0.2067
# Epoch:400, Loss:0.2555
